# %% [markdown]
# <a href="https://colab.research.google.com/github/HunterVinic/Machine-Learning-with-Python/blob/main/Data%20Partition%20of%20Housig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = "/content/drive/MyDrive/datamining/WestRoxbury.csv"
housing_df = pd.read_csv(file_path)
housing_df.head()
# Out:
#    TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  FLOORS   \
# 0         344.2  4330       9965      1880         2436         1352      2.0
# 1         412.6  5190       6590      1945         3108         1976      2.0
# 2         330.1  4152       7500      1890         2294         1371      2.0
# 3         498.6  6272      13773      1957         5032         2608      1.0
# 4         331.5  4170       5000      1910         2370         1438      2.0
#
#    ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE REMODEL
# 0      6          3          1          1        1          0    None
# 1     10          4          2          1        1          0  Recent
# 2      8          4          1          1        1          0    None
# 3      9          5          1          1        1          1    None
# 4      7          3          2          0        1          0    None

# %%
print(housing_df.shape)
housing_df
housing_df.head()
# Out:
# (5802, 14)
#    TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  FLOORS   \
# 0         344.2  4330       9965      1880         2436         1352      2.0
# 1         412.6  5190       6590      1945         3108         1976      2.0
# 2         330.1  4152       7500      1890         2294         1371      2.0
# 3         498.6  6272      13773      1957         5032         2608      1.0
# 4         331.5  4170       5000      1910         2370         1438      2.0
#
#    ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE REMODEL
# 0      6          3          1          1        1          0    None
# 1     10          4          2          1        1          0  Recent
# 2      8          4          1          1        1          0    None
# 3      9          5          1          1        1          1    None
# 4      7          3          2          0        1          0    None

# %% [markdown]
# ##Rename Columns: Replace spaces with _ to allow dot notation

# %%
housing_df = housing_df.rename(columns = {'TOTAL VALUE ':"TOTAL_VALUE"})
housing_df.columns = [s.strip().replace(' ','_') for s in housing_df.columns]
housing_df.head()
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
# 4        331.5  4170      5000      1910        2370         1438     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0    None
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0    None
# 3      9         5          1          1        1          1    None
# 4      7         3          2          0        1          0    None

# %%
housing_df.loc[0:3]
housing_df.iloc[0:3]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0    None
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0    None

# %%
housing_df['TOTAL_VALUE'].iloc[0:10]
housing_df.iloc[0:10]['TOTAL_VALUE']
housing_df.iloc[0:10].TOTAL_VALUE
# Out:
# 0    344.2
# 1    412.6
# 2    330.1
# 3    498.6
# 4    331.5
# 5    337.4
# 6    359.4
# 7    320.4
# 8    333.5
# 9    409.4
# Name: TOTAL_VALUE, dtype: float64

# %%
housing_df.iloc[4, 0:5]
housing_df.iloc[4:5, 0:10]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 4        331.5  4170      5000      1910        2370         1438     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH
# 4      7         3          2

# %%
s1= housing_df.iloc[0:2, 0:2]
s2= housing_df.iloc[0:2,4:6]
pd.concat([s1,s2], axis= 1)
# Out:
#    TOTAL_VALUE   TAX  GROSS_AREA  LIVING_AREA
# 0        344.2  4330        2436         1352
# 1        412.6  5190        3108         1976

# %%
housing_df.describe()
# Out:
#        TOTAL_VALUE           TAX      LOT_SQFT     YR_BUILT   GROSS_AREA  \
# count  5802.000000   5802.000000   5802.000000  5802.000000  5802.000000
# mean    392.685715   4939.485867   6278.083764  1936.744916  2924.842123
# std      99.177414   1247.649118   2669.707974    35.989910   883.984726
# min     105.000000   1320.000000    997.000000     0.000000   821.000000
# 25%     325.125000   4089.500000   4772.000000  1920.000000  2347.000000
# 50%     375.900000   4728.000000   5683.000000  1935.000000  2700.000000
# 75%     438.775000   5519.500000   7022.250000  1955.000000  3239.000000
# max    1217.800000  15319.000000  46411.000000  2011.000000  8154.000000
#
#        LIVING_AREA       FLOORS        ROOMS     BEDROOMS    FULL_BATH  \
# count  5802.000000  5802.000000  5802.000000  5802.000000  5802.000000
# mean   1657.065322     1.683730     6.994829     3.230093     1.296794
# std     540.456726     0.444884     1.437657     0.846607     0.522040
# ...

# %%
housing_df.sample(100)
# Out:
#       TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 4267        467.2  5877      6128      1955        3007         1530     2.0
# 2938        310.5  3906      5000      1958        2148          936     1.0
# 2101        457.7  5757      9006      1930        2770         1666     2.0
# 4495        381.8  4803      5500      1920        2796         1800     2.0
# 1787        369.5  4648      4454      1947        2658         1400     2.0
# ...           ...   ...       ...       ...         ...          ...     ...
# 5571        368.9  4640      5000      1938        2805         1800     2.0
# 2205        439.0  5522      6353      1951        2770         1432     2.0
# 2012        459.9  5785      5750      1951        3109         1869     2.0
# 516         290.2  3650      5963      1963        2164         1008     1.0
# 2787        359.6  4523      5500      1920        2377         1350     2.0
#
# ...

# %%
weights = [0.9 if rooms  > 10 else 0.01 for rooms in housing_df.ROOMS]
housing_df.sample(100, weights = weights)
# Out:
#       TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 1467        773.5  9730      7449      2004        6960         3929     2.0
# 523         437.9  5508      8861      1798        5356         2953     2.0
# 2421        410.6  5165      5278      1930        2696         1360     1.5
# 3767        522.1  6568      6840      1910        4443         2459     2.0
# 3545        417.4  5250      4960      1927        2697         1625     2.0
# ...           ...   ...       ...       ...         ...          ...     ...
# 3861        396.5  4987      6198      1940        3108         1632     1.5
# 3547        349.3  4394      5792      1890        3000         2032     2.0
# 4968        406.0  5107      7660      1950        2252          960     1.0
# 3640        275.5  3465      4718      1930        1884          900     1.0
# 2453        564.7  7103      7676      1907        3596         2360     2.0
#
# ...

# %% [markdown]
# ## Data Preprocessing and Data Cleaning ##

# %%
housing_df.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA',
#        'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH',
#        'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
cat_features = [ col for col in housing_df.columns if housing_df[col].dtype == '0']
print(cat_features)
# Out:
# []

# %%
num_features = [col for col in housing_df.columns if  housing_df[col].dtype != '0']
print(num_features)
# Out:
# ['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA', 'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL']

# %%
housing_df.REMODEL = housing_df.REMODEL.astype('category')
print(housing_df.REMODEL.cat.categories)
print(housing_df.REMODEL.dtype)
# Out:
# Index(['None', 'Old', 'Recent'], dtype='object')
# category

# %% [markdown]
# ## Convert Categorical(Ordinal to Numeric)

# %%
data = {'Temperature':['Hot', 'Cold', 'Warm', 'Hot', 'Warm']}
df = pd.DataFrame(data)

# Import the label encoder #
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

#Fit and Transfrom the ordinal variable #
encoded_data = encoder.fit_transform(df[['Temperature']])
df['Encoded_Temperature'] = encoded_data
df = df.drop(['Temperature'], axis = 1)
df
# Out:
#    Encoded_Temperature
# 0                  1.0
# 1                  0.0
# 2                  2.0
# 3                  1.0
# 4                  2.0

# %%
housing_df = pd.get_dummies(housing_df, prefix_sep ='_', drop_first = True)
housing_df.head(10)
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
# 4        331.5  4170      5000      1910        2370         1438     2.0
# 5        337.4  4244      5142      1950        2124         1060     1.0
# 6        359.4  4521      5000      1954        3220         1916     2.0
# 7        320.4  4030     10000      1950        2208         1200     1.0
# 8        333.5  4195      6835      1958        2582         1092     1.0
# 9        409.4  5150      5093      1900        4818         2992     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE  REMODEL_Old  \
# 0      6         3          1          1        1          0            0
# ...

# %%
housing_df.sort_values(by =['TOTAL_VALUE'] )
# Out:
#       TOTAL_VALUE    TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 325         105.0   1320       997      1910        1319          504     1.0
# 258         144.6   1819      1017      1920        1293          797     1.5
# 244         167.6   2108      1980      1900        1502          690     1.0
# 608         171.8   2161      2313      1912        1862          754     1.0
# 577         176.9   2225      1037      1920        2520         1680     2.0
# ...           ...    ...       ...       ...         ...          ...     ...
# 2118        935.1  11763     25200      1954        6840         5289     1.0
# 3804        936.0  11774     20560      1901        8154         4106     2.0
# 4151        996.9  12541     10050      2006        5392         4375     2.0
# 4179       1009.9  12704     13300      2010        7624         4133     2.0
# 4571       1217.8  15319     46411      1940        7144         4037     2.0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(housing_df['TAX']).set(title= 'Box Plot for Tax')
plt.ylabel ('Tax')
plt.show()

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
fig, axs = plt.subplots(2,2, figsize = (10,8))
sns.boxplot(housing_df['TOTAL_VALUE'], ax = axs[0,0]).set(title= 'BoxPlot for Total Value')
sns.boxplot(housing_df['YR_BUILT'], ax = axs[0,1]).set(title= 'Box Plot for Year Built')
sns.boxplot(housing_df['GROSS_AREA'], ax = axs[1,0]).set(title= 'Box Plot for Gross Area')
sns.boxplot(housing_df['LIVING_AREA'], ax = axs[1,1]).set(title= 'Box Plot for Living Area')
# Out:
# [Text(0.5, 1.0, 'Box Plot for Living Area')]

# %% [markdown]
# ## Missing Value ##

# %%
housing_df.isnull().sum()
# Out:
# TOTAL_VALUE       0
# TAX               0
# LOT_SQFT          0
# YR_BUILT          0
# GROSS_AREA        0
# LIVING_AREA       0
# FLOORS            0
# ROOMS             0
# BEDROOMS          0
# FULL_BATH         0
# HALF_BATH         0
# KITCHEN           0
# FIREPLACE         0
# REMODEL_Old       0
# REMODEL_Recent    0
# dtype: int64

# %%
plt.figure(figsize =(5,4))
sns.heatmap(housing_df.isnull(), cmap ='viridis')
plt.show()

# %%
housing_df.count()
# Out:
# TOTAL_VALUE       5802
# TAX               5802
# LOT_SQFT          5802
# YR_BUILT          5802
# GROSS_AREA        5802
# LIVING_AREA       5802
# FLOORS            5802
# ROOMS             5802
# BEDROOMS          5802
# FULL_BATH         5802
# HALF_BATH         5802
# KITCHEN           5802
# FIREPLACE         5802
# REMODEL_Old       5802
# REMODEL_Recent    5802
# dtype: int64

# %%
import numpy as np
missingRows = housing_df.sample(10).index
housing_df.loc[missingRows,'BEDROOMS'] = np.nan
print("Number of rows aftersetting some values to missing values")
housing_df['BEDROOMS'].count()
# Out:
# Number of rows aftersetting some values to missing values
# 5792

# %%
plt.figure(figsize =(5,4))
sns.heatmap(housing_df.isnull(), cmap ='viridis')
plt.show()

# %%
reduced_df = housing_df.dropna()
len (reduced_df)
# Out:
# 5792

# %%
plt.figure(figsize =(5,4))
sns.heatmap(reduced_df.isnull(), cmap ='viridis')
plt.show()

# %% [markdown]
# # Replace the missing values with median of the remaining values

# %%
medianBedrooms = housing_df ['BEDROOMS'].median()
housing_df.BEDROOMS = housing_df.BEDROOMS.fillna(value = medianBedrooms)
housing_df['BEDROOMS'].count()
# Out:
# 5802

# %% [markdown]
# #Normalize

# %%
housing_df.head()
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
# 4        331.5  4170      5000      1910        2370         1438     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE  REMODEL_Old  \
# 0      6       3.0          1          1        1          0            0
# 1     10       4.0          2          1        1          0            0
# 2      8       4.0          1          1        1          0            0
# 3      9       5.0          1          1        1          1            0
# 4      7       3.0          2          0        1          0            0
#
#    REMODEL_Recent
# 0               0
# 1               1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler ()
norm_df = pd.DataFrame(scaler.fit_transform(housing_df), index = housing_df.index, columns = housing_df.columns)
norm_df.head()
# Out:
#    TOTAL_VALUE       TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0     0.214953  0.215015  0.197472  0.934858    0.220237     0.177220     0.5
# 1     0.276420  0.276448  0.123156  0.967181    0.311878     0.307628     0.5
# 2     0.202283  0.202300  0.143194  0.939831    0.200873     0.181191     0.5
# 3     0.353702  0.353740  0.281323  0.973148    0.574253     0.439707     0.0
# 4     0.203541  0.203586  0.088145  0.949776    0.211237     0.195193     0.5
#
#       ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE  REMODEL_Old  \
# 0  0.272727     0.250       0.00   0.333333      0.0       0.00          0.0
# 1  0.636364     0.375       0.25   0.333333      0.0       0.00          0.0
# 2  0.454545     0.375       0.00   0.333333      0.0       0.00          0.0
# 3  0.545455     0.500       0.00   0.333333      0.0       0.25          0.0
# 4  0.363636     0.250       0.25   0.000000      0.0       0.00          0.0
#
#    REMODEL_Recent
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler ()
scale_df = pd.DataFrame(scaler.fit_transform(housing_df), index = housing_df.index, columns = housing_df.columns)
scale_df.head()
# Out:
#    TOTAL_VALUE       TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  \
# 0    -0.488921 -0.488550  1.381138 -1.576825   -0.553046    -0.564507
# 1     0.200812  0.200806  0.116845  0.229392    0.207214     0.590172
# 2    -0.631102 -0.631230  0.457736 -1.298946   -0.713696    -0.529349
# 3     1.068020  1.068112  2.807634  0.562847    2.383909     1.759654
# 4    -0.616985 -0.616802 -0.478777 -0.743187   -0.627714    -0.405369
#
#      FLOORS     ROOMS  BEDROOMS  FULL_BATH  HALF_BATH   KITCHEN  FIREPLACE  \
# 0  0.710966 -0.692039 -0.271937  -0.568577   0.723264 -0.124814  -1.309450
# 1  0.710966  2.090505  0.909919   1.347151   0.723264 -0.124814  -1.309450
# 2  0.710966  0.699233  0.909919  -0.568577   0.723264 -0.124814  -1.309450
# 3 -1.537005  1.394869  2.091776  -0.568577   0.723264 -0.124814   0.460275
# 4  0.710966  0.003597 -0.271937   1.347151  -1.150120 -0.124814  -1.309450
#
#    REMODEL_Old  REMODEL_Recent
# 0    -0.333589       -0.421418
# ...

# %% [markdown]
# #Data Partition in Python

# %%
from sklearn.model_selection import train_test_split
train_data, valid_data = train_test_split (housing_df, test_size = 0.3, random_state = 1)
print("Training", train_data.shape)
print("Validation:", valid_data.shape)

#training (50%), validation(30%), testing (20%)
train_data, temp = train_test_split(housing_df, test_size = 0.5, random_state =1)
train_data, temp = train_test_split(housing_df, test_size = 0.2, random_state =1)
print("Training:", train_data.shape)
print("Validation:", valid_data.shape)
print("Validation:", valid_data.shape)
# Out:
# Training (4061, 15)
# Validation: (1741, 15)
# Training: (4641, 15)
# Validation: (1741, 15)
# Validation: (1741, 15)

# %% [markdown]
# #Building the Model

# %%
from sklearn.linear_model import LinearRegression

#Create the list of prediction and Outcome (Target)
X = housing_df.drop(["TOTAL_VALUE", "TAX"], axis = 1)
y = housing_df['TOTAL_VALUE']

#Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.4, random_state = 1)

#Model
model = LinearRegression()

#Fit the model on training data
model.fit (X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Making Prediction on Training Data

# %%
y_pred_train = model.predict(X_train)
result_train = pd.DataFrame({"True_value(Toral_value)": y_train,
                            "Predicted_value": y_pred_train,
                             "Residual": y_train- y_pred_train})
result_train.head(10)
# Out:
#       True_value(Toral_value)  Predicted_value   Residual
# 2024                    392.0       387.721587   4.278413
# 5140                    476.3       430.788229  45.511771
# 5259                    367.4       384.034323 -16.634323
# 421                     350.3       369.006002 -18.706002
# 1401                    348.1       314.753082  33.346918
# 2617                    528.9       522.655287   6.244713
# 2083                    426.4       386.725565  39.674435
# 963                     351.8       431.048329 -79.248329
# 1101                    344.9       375.750079 -30.850079
# 3084                    270.7       256.686541  14.013459

# %% [markdown]
# # Making Prediction on Test Data

# %%
y_pred_test = model.predict(X_test)
result_test = pd.DataFrame({"True_value(Toral_value)": y_test,
                            "Predicted_value": y_pred_test,
                             "Residual": y_test - y_pred_test})
result_test.head(10)
# Out:
#       True_value(Toral_value)  Predicted_value   Residual
# 1822                    462.0       406.939471  55.060529
# 1998                    370.4       362.883593   7.516407
# 5126                    407.4       390.287796  17.112204
# 808                     316.1       382.472376 -66.372376
# 4034                    393.2       434.335405 -41.135405
# 4683                    554.3       471.348665  82.951335
# 3375                    426.0       473.773112 -47.773112
# 3696                    621.5       557.036835  64.463165
# 3211                    354.2       378.845873 -24.645873
# 623                     302.9       308.090160  -5.190160

# %% [markdown]
# #Model Evalutaion

# %%
#Model Performance for training data
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import math

#r2_score
r2_score  = r2_score(y_train, y_pred_train)
print ("Performance score of the model on training data:", r2_score*100)

# Mean Square Error
MSE = mean_squared_error(y_train, y_pred_train)
RMSE = math.sqrt(MSE)
print("Root Mean Squared Error:", RMSE)

#Mean Absolute Error
MAE = mean_absolute_error(y_train, y_pred_train)
print("Mean Absolute Error", MAE)
# Out:
# Performance score of the model on training data: 80.97318105157268
# Root Mean Squared Error: 43.031063849658125
# Mean Absolute Error 32.60399885172852

# %%
#Model Performance for testing data
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

#r2_score
r2_score  = r2_score(y_test, y_pred_test)
print ("Performance score of the model on test data:", r2_score*100)

# Mean Square Error
MSE = mean_squared_error(y_test, y_pred_test)
RMSE = math.sqrt(MSE)
print("Root Mean Squared Error:", RMSE)

#Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred_test)
print("Mean Absolute Error", MAE)
# Out:
# Performance score of the model on test data: 81.71366746870544
# Root Mean Squared Error: 42.72878395094849
# Mean Absolute Error 31.965832644443946
