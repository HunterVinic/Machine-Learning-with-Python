# %% [markdown]
# <a href="https://colab.research.google.com/github/HunterVinic/Machine-Learning-with-Python/blob/main/Final_Exam_6128128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### MCQS
# 1. a
#
# 2. d
#
# 3. b
#
# 4. a
#
# 5. c
#
# 6. b
#
# 7.  d
#
# 8. c
#
# 9. d
#
# 10. a

# %% [markdown]
# #### Q11
# ##### a.Overall Error Rate = (FP + FN) / Total Number of Records
# ##### b. Overall Error Rate = (32 + 58) / (88 + 952)
# ##### c. Overall Error Rate = 90 / 1040
# #####d. Overall Error Rate ≈ 0.0865
#
#
# #####So, the overall error rate for this classification model is approximately 0.0865, or 8.65%. This means that the model incorrectly classifies about 8.65% of the records in the dataset.

# %% [markdown]
# #### Q12 To reduce the Number of Predictors, we can:
#  ##### a. Start with the Domain Knoweledge and trim down the predictor set.
#  ##### b. Remove Predictors which have high missing values, not relevant to the analysis and  inaccurate.
#  ##### c. Analyze Summary statistic, frequency table and missing value pattern to evaluate predictors.
#  ##### d. Use computation methods such as Exhaustive Search and Partial Model Search .

# %% [markdown]
# #### Q13 In KNN we determine the neighbour by Categorical Outcome:
# ##### a. Identify the similar records, in the training dataset to new record for classification.
# ##### b. Classify the new neighbout based on the predominantclass of these neighbour
# ##### c. We mesure the Eculidean distance between the neighbour which is like finding the simalirities in predicted values among the dataset.
# ##### d. After finding the distance between the records, The Classification will be basend on the distance which are closer to the Single closest neighbour.

# %% [markdown]
# #### Q14 Naive Bayers Classification is a probabilistic machine learning method to do the classification. This can give us the prediction based on the  given information.
#
# ##### Example, If there are an event being held at the AU Mall, there is high chance that there will be food stall present to sell some food.
#
# ###### Formula:   P(A|B) ={P(B|A).P(A)}/{P(B)}

# %% [markdown]
# #### Q15

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = "/content/drive/MyDrive/datamining/BostonHousing.csv"
f1_df = pd.read_csv(file_path)
f1_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT. MEDV
# 0   4.98  24.0          0
# 1   9.14  21.6          0
# 2   4.03  34.7          1
# 3   2.94  33.4          1
# 4   5.33  36.2          1

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

trainData, ValidData = train_test_split(f1_df, test_size = 0.2, random_state=26)
scaler = StandardScaler()

# %%
predictors =['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','RAD','TAX','PTRATIO','LSTAT']
outcome =['CAT. MEDV']

# %%
scaler.fit(trainData[predictors])

f1Norm = scaler.transform(f1_df[predictors])
f1Norm = pd.DataFrame(f1Norm, columns= ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','RAD','TAX','PTRATIO','LSTAT'])
f1Norm = pd.concat([f1Norm, f1_df[outcome]], axis=1)
f1Norm
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.416721  0.342104 -1.303202 -0.267615 -0.152389  0.393729 -0.148766
# 1   -0.414210 -0.468116 -0.602774 -0.267615 -0.761865  0.176458  0.347610
# 2   -0.414213 -0.468116 -0.602774 -0.267615 -0.761865  1.254347 -0.297316
# 3   -0.413605 -0.468116 -1.322331 -0.267615 -0.859028  0.990518 -0.851663
# 4   -0.409218 -0.468116 -1.322331 -0.267615 -0.859028  1.200735 -0.547316
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.409986 -0.468116  0.112368 -0.267615  0.156766  0.419124 -0.007462
# 502 -0.412062 -0.468116  0.112368 -0.267615  0.156766 -0.248208  0.267900
# 503 -0.410210 -0.468116  0.112368 -0.267615  0.156766  0.959480  0.786015
# 504 -0.404370 -0.468116  0.112368 -0.267615  0.156766  0.702705  0.724421
# 505 -0.411806 -0.468116  0.112368 -0.267615  0.156766 -0.375185  0.416451
#
#           RAD       TAX   PTRATIO     LSTAT  CAT. MEDV
# ...

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors(n_neighbors= 5)

f1Norm = f1Norm.iloc[trainData.index]
f1Norm
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 63  -0.402348  0.657189 -0.888242 -0.267615 -0.903193  0.657558 -0.938620
# 154 -0.248387 -0.468116  1.238056  3.736705  2.788998 -0.235511  0.967175
# 70  -0.406921 -0.468116 -0.052438 -0.267615 -1.256513  0.170814 -2.271951
# 415  1.745349 -0.468116  1.020276 -0.267615  1.093063  0.194799  1.112102
# 152 -0.282743 -0.468116  1.238056  3.736705  2.788998 -1.811431  0.677320
# ..        ...       ...       ...       ...       ...       ...       ...
# 449  0.482596 -0.468116  1.020276 -0.267615  1.393385  0.170814  1.050508
# 432  0.353199 -0.468116  1.020276 -0.267615  0.253929  0.182101  0.199060
# 262 -0.355270  0.432128 -1.058935 -0.267615  0.810408  2.965709  0.804131
# 318 -0.369397 -0.468116 -0.186343 -0.267615 -0.099391  0.121434 -0.076302
# 309 -0.375690 -0.468116 -0.186343 -0.267615 -0.099391 -0.457014  0.267900
#
#           RAD       TAX   PTRATIO     LSTAT  CAT. MEDV
# ...

# %%
newf1 = pd.DataFrame([{'CRIM':0.2,'ZN':0,'INDUS':7,'CHAS':0,'NOX':0.538,'RM':6,'AGE':62,'RAD':4,'TAX':307,'PTRATIO':21,'LSTAT':10}])
newf1
# Out:
#    CRIM  ZN  INDUS  CHAS    NOX  RM  AGE  RAD  TAX  PTRATIO  LSTAT
# 0   0.2   0      7     0  0.538   6   62    4  307       21     10

# %%
newf1norm = pd.DataFrame(scaler.transform(newf1), columns =['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','RAD','TAX','PTRATIO','LSTAT'])
newf1norm
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX       RM       AGE  \
# 0 -0.393557 -0.468116 -0.613075 -0.267615 -0.152389 -0.41751 -0.264708
#
#         RAD       TAX   PTRATIO     LSTAT
# 0 -0.629534 -0.599648  1.206362 -0.371219

# %%
from sklearn.neighbors import NearestNeighbors

# %%
knn.fit(f1Norm[predictors])
distances, indices = knn.kneighbors(newf1norm)
nearest_neighbours = f1Norm.iloc[indices[0],:]
nearest_neighbours
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 13  -0.342160 -0.468116 -0.445325 -0.267615 -0.152389 -0.489464 -0.271954
# 15  -0.342444 -0.468116 -0.445325 -0.267615 -0.152389 -0.651712 -0.463983
# 19  -0.330674 -0.468116 -0.445325 -0.267615 -0.152389 -0.802673  0.007031
# 337 -0.413839 -0.468116 -0.879414 -0.267615 -0.355548 -0.565650 -0.351664
# 110 -0.404568 -0.468116 -0.383523 -0.267615 -0.311383 -0.142395 -0.540069
#
#           RAD       TAX   PTRATIO     LSTAT  CAT. MEDV
# 13  -0.629534 -0.599648  1.206362 -0.610804          0
# 15  -0.629534 -0.599648  1.206362 -0.581889          0
# 19  -0.629534 -0.599648  1.206362 -0.194972          0
# 337 -0.513718 -1.094357  0.826198 -0.294111          0
# 110 -0.513718 -0.140702  1.158841  0.041860          0

# %% [markdown]
# ###### K=1  will remember the correct label and this classifier will achieve 0 error rate

# %% [markdown]
# #### Q16

# %%
import pandas as pd
file_path = "/content/drive/MyDrive/datamining/Cereals.csv"
f2_df = pd.read_csv(file_path)
f2_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4             Almond_Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN        25      3     1.0  0.75  34.384843

# %%
f2_df.fillna(0, inplace=True)
f2_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4             Almond_Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     0.0        25      3     1.0  0.75  34.384843

# %%
from sklearn.metrics import pairwise_distances

numerical_data = f2_df.select_dtypes(include =['float64','int64'])
distances = pairwise_distances(numerical_data, metric ='euclidean')

distance_df = pd.DataFrame(distances, index = f2_df['name'], columns =  f2_df['name'])

distance_df.head(10)
# Out:
# name                        100%_Bran  100%_Natural_Bran    All-Bran  \
# name
# 100%_Bran                    0.000000         196.606553  136.332663
# 100%_Natural_Bran          196.606553           0.000000  313.207176
# All-Bran                   136.332663         313.207176    0.000000
# All-Bran_with_Extra_Fiber   60.845846         250.949947  126.992546
# Almond_Delight             293.646743         230.699422  329.172008
# Apple_Cinnamon_Cheerios    223.249581         179.498135  267.390429
# Apple_Jacks                256.034222         154.672737  323.699839
# Basic_4                    208.861226         200.233623  234.909473
# Bran_Chex                  172.745301         190.150532  205.497722
# Bran_Flakes                123.368547         207.404829  141.037117
#
# name                       All-Bran_with_Extra_Fiber  Almond_Delight  \
# name
# 100%_Bran                                  60.845846      293.646743
# ...

# %%
f2_df_norm =(numerical_data - numerical_data.mean())/numerical_data.std()

distances_scaled = pairwise_distances(f2_df_norm, metric ='euclidean')

scaled_distance_df = pd.DataFrame(distances_scaled, index =f2_df['name'], columns =  f2_df['name'])

scaled_distance_df.head(10)
# Out:
# name                       100%_Bran  100%_Natural_Bran  All-Bran  \
# name
# 100%_Bran                   0.000000           7.533666  1.891770
# 100%_Natural_Bran           7.533666           0.000000  7.775626
# All-Bran                    1.891770           7.775626  0.000000
# All-Bran_with_Extra_Fiber   3.388945          10.034910  4.041421
# Almond_Delight              7.265483           4.799474  7.079489
# Apple_Cinnamon_Cheerios     7.035752           4.854340  6.869431
# Apple_Jacks                 7.511056           5.906575  7.564591
# Basic_4                     7.249501           5.257904  6.902297
# Bran_Chex                   5.615251           6.142390  5.372378
# Bran_Flakes                 4.085946           6.453938  3.702724
#
# name                       All-Bran_with_Extra_Fiber  Almond_Delight  \
# name
# 100%_Bran                                   3.388945        7.265483
# 100%_Natural_Bran                          10.034910        4.799474
# ...

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
Z= linkage(f2_df_norm, method= 'single')

plt.figure(figsize = (10,7))
dendrogram = dendrogram(Z, labels= f2_df['name'].values, orientation='top', leaf_rotation= 90, leaf_font_size= 10)

plt.title('Dendrogram for Single Linkage')
plt.xlabel('Name of Breakfast Cereals.')
plt.ylabel('Eculidean Distances')
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

 #Perform Hierarchical Clustering using complete Linkage Method
Z= linkage(f2_df_norm, method= 'complete')
#Plot Dendrogram
plt.figure(figsize = (10,7))
dendrogram = dendrogram(Z, labels= f2_df['name'].values, orientation='top', leaf_rotation= 90, leaf_font_size= 10)

plt.title('Dendrogram for Complete Linkage')
plt.xlabel('Name of Breakfast Cereals')
plt.ylabel('Eculidean Distances')
plt.show()

# %% [markdown]
# ### The longest line that has not been crossed by any other lines is the 4th line from the top. Therefore the number of clusters should be 9-10.
